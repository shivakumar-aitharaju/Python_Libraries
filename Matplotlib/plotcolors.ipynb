# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv('Ice Cream Ratings.csv')
a = df['Date']
b = df['Texture Rating']
c = df['Flavor Rating']
fig = plt.figure()
ax = fig.add_axes([0,0,1,1]) 
ax.plot(a,b,color = "#ab21ab", lw = 3, alpha = 0.5,ls ='--', marker = 'o') #HEX Code and LINE WIDTH

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1]) 
ax.plot(a,c,color = "#0021ab", lw = 3,ls ='-', marker = 'o', markersize = 20,
         markerfacecolor = 'yellow', markeredgewidth = 3, markeredgecolor = '#000')
