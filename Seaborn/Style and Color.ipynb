# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')
tips.head()
# from qbstyles import mpl_style

import mplcyberpunk
def plot():
    plt.style.use('cyberpunk')

plot()

# def plot(dark):
#     mpl_style(dark)

# plot(dark = True)

# %%
# Styles = ticks, white, darkgrid, whitegrid
sns.set_style('darkgrid')
sns.countplot(x = 'sex',data = tips, hue='smoker')

# sns.despine(left=True, bottom=True) # top and right lines are disabled
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='sex', data=tips, hue = 'day')

#sns.set_context('poster') Is giving ERROR
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#sns.set_context('poster', font_scale=1)
sns.countplot(x='sex', data = tips, hue='time')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#Try palettes such as plasma, viridis, magma, inferno.... more? Google: matplotlib colormaps 
sns.lmplot(x='total_bill', y= 'tip',data=tips, hue='smoker')
